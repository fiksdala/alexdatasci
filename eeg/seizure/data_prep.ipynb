# %%
import os
import wfdb
import numpy as np
import pandas as pd
import pyedflib

# %%
# DOWNLOAD RECORD INFORMATION FILES
wfdb.dl_files('chbmit',dl_dir='record_info',
              files=['RECORDS','RECORDS-WITH-SEIZURES'])
# Out:
# Downloading files...
# Finished downloading files

# %%
# Get channels, start-end, and seizure start-end for all files in subject
def get_sub_info(file):
    subject = [i[:-1] for i in open(file, 'r')]
    file_chans = {}
    start_end = {}
    seiz_start_end = {}
    collect_seiz_time = False
    for i in subject:
        if 'Channel 1:' in i:
            collect_chan = True
            channel_group = {}
        if 'Channel' not in i:
            collect_chan = False
        if collect_chan:
            channel_group[i.split(':')[0]] = i.split(':')[1].strip()
        if 'File Name:' in i:
            f_name = i.split(':')[1].strip()
            file_chans[f_name] = channel_group
            start_end[f_name] = []
        if i.split(':')[0]=='Number of Seizures in File' \
        and float(i.split(':')[1].strip())>0:
            s_e = []
            seiz_start_end[f_name] = []
        if ('Seizure' in i and 'Start' in i):
            collect_seiz_time = True
        if i=='':
            collect_seiz_time = False
        if collect_seiz_time:
            s_e.append(float(i.split(':')[1].strip().split(' ')[0]))
            seiz_start_end[f_name] = s_e
        if 'File Start Time' in i:
            s_time = i.split(': ')[1]
        if 'File End Time' in i:
            start_end[f_name] = [s_time,i.split(': ')[1]]
    return file_chans, start_end, seiz_start_end

# %%
# Get and combine file_chans, start_end, and seiz_start_end for all subjects
sub_files = ['record_info/' + i for i in \
             os.listdir('record_info') if 'summary' in i]
file_chans = {}
file_s_e = {}
file_seize_s_e = {}

for i in sub_files:
    fc, se, sse = get_sub_info(i)
    file_chans.update(fc)
    file_s_e.update(se)
    file_seize_s_e.update(sse)

# %%
# Get list of seizure files, only all electrodes
seizure_files = list(file_seize_s_e.keys())
seizure_electrodes = [file_chans[i].values() for i in seizure_files]
matched_electrodes = [i for i in range(len(seizure_electrodes)) \
                      if len(set(seizure_electrodes[0]).intersection\
                             (seizure_electrodes[i]))==22]
seizures = np.array(seizure_files)[matched_electrodes]

# %%
# Get list of no seizure files, only all electrodes, subset same len
no_seizure_files = [i for i in file_chans.keys() if i not in seizure_files]
no_seizure_electrodes = [file_chans[i].values() for i in no_seizure_files]
matched_electrodes = [i for i in range(len(no_seizure_electrodes)) \
                      if len(set(no_seizure_electrodes[0]).intersection\
                             (no_seizure_electrodes[i]))==22]
no_seizures = np.array(no_seizure_files)[matched_electrodes]
np.random.seed(1234)
no_seizures = np.random.choice(no_seizures,len(seizures),replace=False)

# %%
# Get seizures (just once, takes some time)
# s_getfiles = [i[:5]+'/'+i for i in seizures]
# wfdb.dl_files('chbmit',
#               dl_dir='seizure_edf',
#               keep_subdirs=False,
#               files=s_getfiles)

# %%
# Get seizures (just once, takes some time)
# ns_getfiles = [i[:5]+'/'+i for i in no_seizures]
# wfdb.dl_files('chbmit',
#               dl_dir='no_seizure_edf',
#               keep_subdirs=False,
#               files=ns_getfiles)

# %%
chan_order = [i for i in seizure_electrodes[0]]
print(chan_order)
# Out:
# ['FP1-F7', 'F7-T7', 'T7-P7', 'P7-O1', 'FP1-F3', 'F3-C3', 'C3-P3', 'P3-O1', 'FP2-F4', 'F4-C4', 'C4-P4', 'P4-O2', 'FP2-F8', 'F8-T8', 'T8-P8', 'P8-O2', 'FZ-CZ', 'CZ-PZ', 'P7-T7', 'T7-FT9', 'FT9-FT10', 'FT10-T8', 'T8-P8']

# %%
# Drop 2nd 'T8-P8' label to keep unique keys
chan_order = chan_order[:-1]
chan_order_dict = dict(zip(chan_order,range(len(chan_order))))

# %%
# Get indices of rows to keep and order (keep_ind, order)
s_keep_inds = []
for file in seizures:
    keep_ind = []
    for i in range(len(file_chans[file].values())):
        e = list(file_chans[file].values())[i]
        if e in chan_order:
            keep_ind.append((i,chan_order_dict[e]))
    s_keep_inds.append(keep_ind)
            
ns_keep_inds = []
for file in no_seizures:
    keep_ind = []
    for i in range(len(file_chans[file].values())):
        e = list(file_chans[file].values())[i]
        if e in chan_order:
            keep_ind.append((i,chan_order_dict[e]))
    ns_keep_inds.append(keep_ind)

# %%
# Do all keep_inds end in duplicate (14) (yes, both equal 0 here)?
print(sum([np.array(i)[len(i)-1,1]!=14 for i in s_keep_inds]),
     sum([np.array(i)[len(i)-1,1]!=14 for i in ns_keep_inds]))
# Out:
# 0 0

# %%
# Drop final row of keep_inds to drop duplicate
s_keep_inds = [i[:-1] for i in s_keep_inds]
ns_keep_inds = [i[:-1] for i in ns_keep_inds]

# %%
def seiz_samp_range(file,window=5,padding=5):
    '''Returns sample numbers that captures window leading up to 
    the start of the first seizure on record for each file. In order
    to avoid modeling the seizure itself, padding (in sec) before onset.
    Samples at 256 Hz'''
    end = file_seize_s_e[file][0]*256 - padding*256
    start = end-(window*60*256)
    return (start,end)

# %%
# Get all seizure sequences
s_array = []
for i in range(len(seizures)):
    file = seizures[i]
    print('start ', file)
    f = pyedflib.EdfReader('seizure_edf/'+file)
    edf_import = [f.readSignal(
        chn = e,
        start = seiz_samp_range(file)[0], 
        n = 5*60*256) for e in np.array(s_keep_inds[i])[:,0] ]
    edf_import = np.array(edf_import)[np.array(s_keep_inds[i])[:,1]]
    s_array.append(edf_import)
    f._close()
    print('completed ', file)
# Out:
# start  chb03_01.edf
# completed  chb03_01.edf
# start  chb03_02.edf
# completed  chb03_02.edf
# start  chb03_03.edf
# completed  chb03_03.edf
# start  chb03_04.edf
# completed  chb03_04.edf
# start  chb03_34.edf
# completed  chb03_34.edf
# start  chb03_35.edf
# completed  chb03_35.edf
# start  chb03_36.edf
# completed  chb03_36.edf
# start  chb16_10.edf
# completed  chb16_10.edf
# start  chb16_11.edf
# completed  chb16_11.edf
# start  chb16_14.edf
# completed  chb16_14.edf
# start  chb16_16.edf
# completed  chb16_16.edf
# start  chb16_17.edf
# completed  chb16_17.edf
# start  chb24_01.edf
# completed  chb24_01.edf
# start  chb24_03.edf
# completed  chb24_03.edf
# start  chb24_04.edf
# completed  chb24_04.edf
# start  chb24_06.edf
# completed  chb24_06.edf
# start  chb24_07.edf
# completed  chb24_07.edf
# start  chb24_09.edf
# completed  chb24_09.edf
# start  chb24_11.edf
# completed  chb24_11.edf
# start  chb24_13.edf
# completed  chb24_13.edf
# start  chb24_14.edf
# completed  chb24_14.edf
# start  chb24_15.edf
# completed  chb24_15.edf
# start  chb24_17.edf
# completed  chb24_17.edf
# start  chb24_21.edf
# completed  chb24_21.edf
# start  chb13_19.edf
# completed  chb13_19.edf
# start  chb13_21.edf
# completed  chb13_21.edf
# start  chb13_55.edf
# completed  chb13_55.edf
# start  chb13_58.edf
# completed  chb13_58.edf
# start  chb13_59.edf
# completed  chb13_59.edf
# start  chb13_60.edf
# completed  chb13_60.edf
# start  chb13_62.edf
# completed  chb13_62.edf
# start  chb21_19.edf
# completed  chb21_19.edf
# start  chb21_20.edf
# completed  chb21_20.edf
# start  chb21_21.edf
# completed  chb21_21.edf
# start  chb21_22.edf
# completed  chb21_22.edf
# start  chb06_01.edf
# completed  chb06_01.edf
# start  chb06_04.edf
# completed  chb06_04.edf
# start  chb06_09.edf
# completed  chb06_09.edf
# start  chb06_10.edf
# completed  chb06_10.edf
# start  chb06_13.edf
# completed  chb06_13.edf
# start  chb06_18.edf
# completed  chb06_18.edf
# start  chb06_24.edf
# completed  chb06_24.edf
# start  chb05_06.edf
# completed  chb05_06.edf
# start  chb05_13.edf
# completed  chb05_13.edf
# start  chb05_16.edf
# completed  chb05_16.edf
# start  chb05_17.edf
# completed  chb05_17.edf
# start  chb05_22.edf
# completed  chb05_22.edf
# start  chb19_28.edf
# completed  chb19_28.edf
# start  chb19_29.edf
# completed  chb19_29.edf
# start  chb19_30.edf
# completed  chb19_30.edf
# start  chb22_20.edf
# completed  chb22_20.edf
# start  chb22_25.edf
# completed  chb22_25.edf
# start  chb22_38.edf
# completed  chb22_38.edf
# start  chb10_12.edf
# completed  chb10_12.edf
# start  chb10_20.edf
# completed  chb10_20.edf
# start  chb10_27.edf
# completed  chb10_27.edf
# start  chb10_30.edf
# completed  chb10_30.edf
# start  chb10_31.edf
# completed  chb10_31.edf
# start  chb10_38.edf
# completed  chb10_38.edf
# start  chb10_89.edf
# completed  chb10_89.edf
# start  chb09_06.edf
# completed  chb09_06.edf
# start  chb09_08.edf
# completed  chb09_08.edf
# start  chb09_19.edf
# completed  chb09_19.edf
# start  chb15_06.edf
# completed  chb15_06.edf
# start  chb15_10.edf
# completed  chb15_10.edf
# start  chb15_15.edf
# completed  chb15_15.edf
# start  chb15_17.edf
# completed  chb15_17.edf
# start  chb15_20.edf
# completed  chb15_20.edf
# start  chb15_22.edf
# completed  chb15_22.edf
# start  chb15_28.edf
# completed  chb15_28.edf
# start  chb15_31.edf
# completed  chb15_31.edf
# start  chb15_40.edf
# completed  chb15_40.edf
# start  chb15_46.edf
# completed  chb15_46.edf
# start  chb15_49.edf
# completed  chb15_49.edf
# start  chb15_52.edf
# completed  chb15_52.edf
# start  chb15_54.edf
# completed  chb15_54.edf
# start  chb15_62.edf
# completed  chb15_62.edf
# start  chb07_12.edf
# completed  chb07_12.edf
# start  chb07_13.edf
# completed  chb07_13.edf
# start  chb07_19.edf
# completed  chb07_19.edf
# start  chb20_12.edf
# completed  chb20_12.edf
# start  chb20_13.edf
# completed  chb20_13.edf
# start  chb20_14.edf
# completed  chb20_14.edf
# start  chb20_15.edf
# completed  chb20_15.edf
# start  chb20_16.edf
# completed  chb20_16.edf
# start  chb20_68.edf
# completed  chb20_68.edf
# start  chb12_06.edf
# completed  chb12_06.edf
# start  chb12_08.edf
# completed  chb12_08.edf
# start  chb12_09.edf
# completed  chb12_09.edf
# start  chb12_10.edf
# completed  chb12_10.edf
# start  chb12_11.edf
# completed  chb12_11.edf
# start  chb12_23.edf
# completed  chb12_23.edf
# start  chb12_33.edf
# completed  chb12_33.edf
# start  chb12_36.edf
# completed  chb12_36.edf
# start  chb12_38.edf
# completed  chb12_38.edf
# start  chb12_42.edf
# completed  chb12_42.edf
# start  chb17a_03.edf
# completed  chb17a_03.edf
# start  chb17a_04.edf
# completed  chb17a_04.edf
# start  chb17b_63.edf
# completed  chb17b_63.edf
# start  chb02_16.edf
# completed  chb02_16.edf
# start  chb02_16+.edf
# completed  chb02_16+.edf
# start  chb02_19.edf
# completed  chb02_19.edf
# start  chb01_03.edf
# completed  chb01_03.edf
# start  chb01_04.edf
# completed  chb01_04.edf
# start  chb01_15.edf
# completed  chb01_15.edf
# start  chb01_16.edf
# completed  chb01_16.edf
# start  chb01_18.edf
# completed  chb01_18.edf
# start  chb01_21.edf
# completed  chb01_21.edf
# start  chb01_26.edf
# completed  chb01_26.edf
# start  chb14_03.edf
# completed  chb14_03.edf
# start  chb14_04.edf
# completed  chb14_04.edf
# start  chb14_06.edf
# completed  chb14_06.edf
# start  chb14_11.edf
# completed  chb14_11.edf
# start  chb14_17.edf
# completed  chb14_17.edf
# start  chb14_18.edf
# completed  chb14_18.edf
# start  chb14_27.edf
# completed  chb14_27.edf
# start  chb08_02.edf
# completed  chb08_02.edf
# start  chb08_05.edf
# completed  chb08_05.edf
# start  chb08_11.edf
# completed  chb08_11.edf
# start  chb08_13.edf
# completed  chb08_13.edf
# start  chb08_21.edf
# completed  chb08_21.edf
# start  chb11_82.edf
# completed  chb11_82.edf
# start  chb11_92.edf
# completed  chb11_92.edf
# start  chb11_99.edf
# completed  chb11_99.edf
# start  chb23_06.edf
# completed  chb23_06.edf
# start  chb23_08.edf
# completed  chb23_08.edf
# start  chb23_09.edf
# completed  chb23_09.edf
# start  chb18_29.edf
# completed  chb18_29.edf
# start  chb18_30.edf
# completed  chb18_30.edf
# start  chb18_31.edf
# completed  chb18_31.edf
# start  chb18_32.edf
# completed  chb18_32.edf
# start  chb18_35.edf
# completed  chb18_35.edf
# start  chb18_36.edf
# completed  chb18_36.edf
# start  chb04_05.edf
# completed  chb04_05.edf
# start  chb04_08.edf
# completed  chb04_08.edf
# start  chb04_28.edf
# completed  chb04_28.edf

# %%
pre_5 = [i for i in range(len(s_array)) if s_array[i].shape[1]==0]
print(f'These seizures happened before 5 minutes: {pre_5}')
X_S = np.array([i for i in s_array if i.shape[1]>0])
X_S_file = seizures[ [i for i in range(len(s_array)) \
                      if s_array[i].shape[1]>0]]
# Out:
# These seizures happened before 5 minutes: [11, 13, 16, 47, 63, 75, 80, 91, 99, 121]

# %%
print(X_S.shape,len(X_S_file))
# Out:
# (126, 22, 76800) 126

# %%
# Get no_seizure controls, 5-minute intervals, randomly starting from
# 10-30 min

# Get all seizure sequences
np.random.seed(1234)
ns_array = []
for i in range(len(no_seizures)):
    file = no_seizures[i]
    print('start ', file)
    f = pyedflib.EdfReader('no_seizure_edf/'+file)
    edf_import = [f.readSignal(
        chn = e,
        start = int(np.random.uniform(10*60*256, 30*60*256)), 
        n = 5*60*256) for e in np.array(ns_keep_inds[i])[:,0] ]
    edf_import = np.array(edf_import)[np.array(ns_keep_inds[i])[:,1]]
    ns_array.append(edf_import)
    f._close()
    print('completed ', file)
# Out:
# start  chb21_18.edf
# completed  chb21_18.edf
# start  chb05_18.edf
# completed  chb05_18.edf
# start  chb08_24.edf
# completed  chb08_24.edf
# start  chb04_22.edf
# completed  chb04_22.edf
# start  chb18_17.edf
# completed  chb18_17.edf
# start  chb17b_59.edf
# completed  chb17b_59.edf
# start  chb05_31.edf
# completed  chb05_31.edf
# start  chb04_14.edf
# completed  chb04_14.edf
# start  chb21_24.edf
# completed  chb21_24.edf
# start  chb10_17.edf
# completed  chb10_17.edf
# start  chb04_10.edf
# completed  chb04_10.edf
# start  chb21_29.edf
# completed  chb21_29.edf
# start  chb09_15.edf
# completed  chb09_15.edf
# start  chb19_14.edf
# completed  chb19_14.edf
# start  chb07_16.edf
# completed  chb07_16.edf
# start  chb11_02.edf
# completed  chb11_02.edf
# start  chb08_19.edf
# completed  chb08_19.edf
# start  chb09_17.edf
# read 0, less than 76800 requested!!!
# read 22379, less than 76800 requested!!!
# read 0, less than 76800 requested!!!
# read 0, less than 76800 requested!!!
# read 0, less than 76800 requested!!!
# read 0, less than 76800 requested!!!
# read 0, less than 76800 requested!!!
# read 13802, less than 76800 requested!!!
# read 0, less than 76800 requested!!!
# read 0, less than 76800 requested!!!
# read 12621, less than 76800 requested!!!
# read 0, less than 76800 requested!!!
# read 65538, less than 76800 requested!!!
# read 0, less than 76800 requested!!!
# read 0, less than 76800 requested!!!
# read 0, less than 76800 requested!!!
# read 0, less than 76800 requested!!!
# read 40836, less than 76800 requested!!!
# read 0, less than 76800 requested!!!
# read 0, less than 76800 requested!!!
# read 0, less than 76800 requested!!!
# completed  chb09_17.edf
# start  chb08_16.edf
# completed  chb08_16.edf
# start  chb01_10.edf
# completed  chb01_10.edf
# start  chb09_10.edf
# completed  chb09_10.edf
# start  chb01_34.edf
# completed  chb01_34.edf
# start  chb01_40.edf
# completed  chb01_40.edf
# start  chb03_12.edf
# completed  chb03_12.edf
# start  chb05_07.edf
# completed  chb05_07.edf
# start  chb21_13.edf
# completed  chb21_13.edf
# start  chb11_27.edf
# completed  chb11_27.edf
# start  chb15_07.edf
# completed  chb15_07.edf
# start  chb01_23.edf
# completed  chb01_23.edf
# start  chb19_05.edf
# completed  chb19_05.edf
# start  chb03_16.edf
# completed  chb03_16.edf
# start  chb03_32.edf
# completed  chb03_32.edf
# start  chb19_12.edf
# completed  chb19_12.edf
# start  chb04_23.edf
# completed  chb04_23.edf
# start  chb02_32.edf
# completed  chb02_32.edf
# start  chb11_08.edf
# completed  chb11_08.edf
# start  chb20_28.edf
# completed  chb20_28.edf
# start  chb11_14.edf
# completed  chb11_14.edf
# start  chb08_03.edf
# completed  chb08_03.edf
# start  chb11_16.edf
# completed  chb11_16.edf
# start  chb11_03.edf
# completed  chb11_03.edf
# start  chb03_37.edf
# completed  chb03_37.edf
# start  chb01_06.edf
# completed  chb01_06.edf
# start  chb02_08.edf
# completed  chb02_08.edf
# start  chb04_04.edf
# completed  chb04_04.edf
# start  chb02_02.edf
# completed  chb02_02.edf
# start  chb08_12.edf
# completed  chb08_12.edf
# start  chb18_09.edf
# completed  chb18_09.edf
# start  chb03_27.edf
# completed  chb03_27.edf
# start  chb04_18.edf
# completed  chb04_18.edf
# start  chb01_39.edf
# completed  chb01_39.edf
# start  chb02_05.edf
# completed  chb02_05.edf
# start  chb22_17.edf
# completed  chb22_17.edf
# start  chb21_31.edf
# completed  chb21_31.edf
# start  chb08_14.edf
# completed  chb08_14.edf
# start  chb21_11.edf
# completed  chb21_11.edf
# start  chb02_12.edf
# completed  chb02_12.edf
# start  chb01_11.edf
# completed  chb01_11.edf
# start  chb08_17.edf
# completed  chb08_17.edf
# start  chb14_39.edf
# completed  chb14_39.edf
# start  chb16_12.edf
# completed  chb16_12.edf
# start  chb18_15.edf
# completed  chb18_15.edf
# start  chb05_30.edf
# completed  chb05_30.edf
# start  chb10_28.edf
# completed  chb10_28.edf
# start  chb01_02.edf
# completed  chb01_02.edf
# start  chb21_25.edf
# completed  chb21_25.edf
# start  chb20_27.edf
# completed  chb20_27.edf
# start  chb17c_04.edf
# completed  chb17c_04.edf
# start  chb22_24.edf
# completed  chb22_24.edf
# start  chb15_30.edf
# completed  chb15_30.edf
# start  chb22_10.edf
# completed  chb22_10.edf
# start  chb02_24.edf
# completed  chb02_24.edf
# start  chb11_61.edf
# completed  chb11_61.edf
# start  chb15_13.edf
# completed  chb15_13.edf
# start  chb21_28.edf
# completed  chb21_28.edf
# start  chb18_06.edf
# completed  chb18_06.edf
# start  chb15_32.edf
# completed  chb15_32.edf
# start  chb01_31.edf
# completed  chb01_31.edf
# start  chb19_04.edf
# completed  chb19_04.edf
# start  chb19_19.edf
# completed  chb19_19.edf
# start  chb15_33.edf
# completed  chb15_33.edf
# start  chb20_23.edf
# completed  chb20_23.edf
# start  chb21_32.edf
# completed  chb21_32.edf
# start  chb19_10.edf
# completed  chb19_10.edf
# start  chb10_07.edf
# completed  chb10_07.edf
# start  chb08_15.edf
# completed  chb08_15.edf
# start  chb17c_05.edf
# completed  chb17c_05.edf
# start  chb20_03.edf
# completed  chb20_03.edf
# start  chb03_18.edf
# completed  chb03_18.edf
# start  chb13_03.edf
# completed  chb13_03.edf
# start  chb03_30.edf
# completed  chb03_30.edf
# start  chb04_29.edf
# completed  chb04_29.edf
# start  chb05_05.edf
# completed  chb05_05.edf
# start  chb12_37.edf
# completed  chb12_37.edf
# start  chb22_03.edf
# completed  chb22_03.edf
# start  chb15_37.edf
# completed  chb15_37.edf
# start  chb11_09.edf
# completed  chb11_09.edf
# start  chb02_35.edf
# completed  chb02_35.edf
# start  chb10_22.edf
# completed  chb10_22.edf
# start  chb07_06.edf
# completed  chb07_06.edf
# start  chb05_28.edf
# completed  chb05_28.edf
# start  chb15_14.edf
# completed  chb15_14.edf
# start  chb15_19.edf
# completed  chb15_19.edf
# start  chb14_19.edf
# completed  chb14_19.edf
# start  chb11_11.edf
# completed  chb11_11.edf
# start  chb22_21.edf
# completed  chb22_21.edf
# start  chb11_01.edf
# completed  chb11_01.edf
# start  chb14_24.edf
# completed  chb14_24.edf
# start  chb03_05.edf
# completed  chb03_05.edf
# start  chb12_34.edf
# completed  chb12_34.edf
# start  chb23_17.edf
# completed  chb23_17.edf
# start  chb09_02.edf
# completed  chb09_02.edf
# start  chb18_04.edf
# completed  chb18_04.edf
# start  chb12_19.edf
# completed  chb12_19.edf
# start  chb22_02.edf
# completed  chb22_02.edf
# start  chb21_05.edf
# completed  chb21_05.edf
# start  chb10_19.edf
# completed  chb10_19.edf
# start  chb01_20.edf
# completed  chb01_20.edf
# start  chb19_22.edf
# completed  chb19_22.edf
# start  chb05_12.edf
# completed  chb05_12.edf
# start  chb06_05.edf
# completed  chb06_05.edf
# start  chb18_21.edf
# completed  chb18_21.edf
# start  chb03_26.edf
# completed  chb03_26.edf
# start  chb21_09.edf
# completed  chb21_09.edf
# start  chb05_23.edf
# completed  chb05_23.edf
# start  chb20_04.edf
# completed  chb20_04.edf
# start  chb13_02.edf
# completed  chb13_02.edf
# start  chb20_06.edf
# completed  chb20_06.edf
# start  chb05_34.edf
# completed  chb05_34.edf
# start  chb15_50.edf
# completed  chb15_50.edf
# start  chb19_03.edf
# completed  chb19_03.edf
# start  chb22_28.edf
# completed  chb22_28.edf
# start  chb04_13.edf
# completed  chb04_13.edf
# start  chb14_42.edf
# completed  chb14_42.edf
# start  chb02_31.edf
# completed  chb02_31.edf
# start  chb02_23.edf
# completed  chb02_23.edf

# %%
np.random.seed(1234)
X_NS_I = np.random.choice(np.concatenate([np.arange(17),
                                          np.arange(18,
                                                    len(no_seizures))]),
                          len(X_S_file))

# %%
X_NS = np.array(ns_array)[X_NS_I]
X_NS_file = no_seizures[X_NS_I]
print(X_S.shape,len(X_S_file),
      X_NS.shape,len(X_NS_file))
# Out:
# (126, 22, 76800) 126 (126, 22, 76800) 126

# %%
print(X_S.shape,len(X_S_file),'\n',
      X_NS.shape,len(X_NS_file))
# Out:
# (126, 22, 76800) 126
#  (126, 22, 76800) 126

# %%
import pickle
pickle.dump(X_NS,open('X_NS.pickle','wb'))
pickle.dump(X_NS_file,open('X_NS_file.pickle','wb'))
pickle.dump(X_S,open('X_S.pickle','wb'))
pickle.dump(X_S_file,open('X_S_file.pickle','wb'))
pickle.dump(chan_order_dict,open('chan_order_dict.pickle','wb'))

# %%
chan_order_dict
# Out:
# {'FP1-F7': 0,
#  'F7-T7': 1,
#  'T7-P7': 2,
#  'P7-O1': 3,
#  'FP1-F3': 4,
#  'F3-C3': 5,
#  'C3-P3': 6,
#  'P3-O1': 7,
#  'FP2-F4': 8,
#  'F4-C4': 9,
#  'C4-P4': 10,
#  'P4-O2': 11,
#  'FP2-F8': 12,
#  'F8-T8': 13,
#  'T8-P8': 14,
#  'P8-O2': 15,
#  'FZ-CZ': 16,
#  'CZ-PZ': 17,
#  'P7-T7': 18,
#  'T7-FT9': 19,
#  'FT9-FT10': 20,
#  'FT10-T8': 21}
